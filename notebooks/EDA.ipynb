# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston

# %%
boston = load_boston()
bos = pd.DataFrame(boston.data,columns = boston.feature_names)
bos['price'] = boston.target
# Out:
# c:\Users\shiva\anaconda3\envs\ineuron_Assignments\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'price'],
#       dtype='object')

# %% [markdown]
# Boston dataset feature info:
#
# CRIM per capita crime rate by town
#
# ZN proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS proportion of non-retail business acres per town
#
# CHAS Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#
# NOX nitric oxides concentration (parts per 10 million)
#
# RM average number of rooms per dwelling
#
# AGE proportion of owner-occupied units built prior to 1940
#
# DIS weighted distances to five Boston employment centres
#
# RAD index of accessibility to radial highways
#
# TAX full-value property-tax rate per $10,000
#
# PTRATIO pupil-teacher ratio by town
#
# B 1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#
# LSTAT % lower status of the population
#
# price Median value of owner-occupied homes in $1000’s

# %%
print(f"Number of columns in the dataset: {bos.shape[1]}")
print(f"Number of rows in the dataset: {bos.shape[0]}")
# Out:
# Number of columns in the dataset: 14
# Number of rows in the dataset: 506

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
## checking for the missing values in the data
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %% [markdown]
# **So,there are no missing values in the data**

# %%
## checking for the outliers in the data
plt.figure(figsize=(12,10))
plt.tight_layout()
bos.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Data seems to have outliers for some of the features**

# %%
## checking the distribution of the features
plt.figure(figsize=(15,15))
sns.set_style('darkgrid')
for i in range(len(bos.columns)):
    plt.subplot(4,4,i+1)
    sns.distplot(bos[bos.columns[i]],color='g')
plt.tight_layout()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2408144305.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bos[bos.columns[i]],color='g')
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2408144305.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
## checking the distribution after applying log-normal distribution
plt.figure(figsize=(15,15))
sns.set_style('darkgrid')
for i in range(len(bos.columns)):
    plt.subplot(4,4,i+1)
    sns.distplot(np.sqrt(bos[bos.columns[i]]),color='m')
plt.tight_layout()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2820006051.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.sqrt(bos[bos.columns[i]]),color='m')
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2820006051.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
## finding the number of unique values in each of the feature values
## if the number of unique values in any of the feature is less than 10, then it can be considered as categorical feature
bos.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# price      229
# dtype: int64

# %% [markdown]
# **Feature namely CHAS and RAD have less than 10 unique values, so we can conclude those two as categorical features**

# %%
## checking the correlation between features of the data
plt.figure(figsize=(12,7))
sns.heatmap(bos.corr(),cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Since RAD and TAX are highly correlated, it makes sense to remove one of those two features**

# %%
Q1_list = []
Q3_list = []
IQR_list = []

for feature in bos.columns.drop(['CHAS','RAD','price']):
    Q1 = np.round(np.percentile(bos[feature],25),2)
    Q1_list.append(Q1)
    Q3 = np.round(np.percentile(bos[feature],75),2)
    Q3_list.append(Q3)
    IQR = np.round(Q3 - Q1,2)
    IQR_list.append(IQR)

print(f"Q1: {Q1_list}")
print()
print(f"Q3: {Q3_list}")
print()
print(f"IQR: {IQR_list}")
# Out:
# Q1: [0.08, 0.0, 5.19, 0.45, 5.89, 45.02, 2.1, 279.0, 17.4, 375.38, 6.95]
#
# Q3: [3.68, 12.5, 18.1, 0.62, 6.62, 94.07, 5.19, 666.0, 20.2, 396.22, 16.96]
#
# IQR: [3.6, 12.5, 12.91, 0.17, 0.73, 49.05, 3.09, 387.0, 2.8, 20.84, 10.01]

# %%
## removing outliers by replacing them with the null values
## here we will exclude features namely CHAS, RAD since they are kind of categorical and price since it is a target column
lst = bos.columns.drop(['CHAS','RAD','price'])
for i in range(len(lst)):
    upper_limit = Q3_list[i] + 1.5*IQR_list[i]
    lower_limit = Q1_list[i] - 1.5*IQR_list[i]

    bos[lst[i]] = np.where((bos[lst[i]] > upper_limit) | (bos[lst[i]] < lower_limit), np.nan, bos[lst[i]])

# %%
bos.isnull().sum()
# Out:
# CRIM       66
# ZN         68
# INDUS       0
# CHAS        0
# NOX         0
# RM         30
# AGE         0
# DIS         5
# RAD         0
# TAX         0
# PTRATIO    15
# B          77
# LSTAT       7
# price       0
# dtype: int64

# %%
## now we will fill the null values using the mean of the values from the column
for feature in bos.columns:
    bos[feature].fillna(np.mean(bos[feature]),inplace=True)

# %%
## checking the null values in the columns again
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
## plotting box plot again
bos.plot.box()
plt.tight_layout()

# %%
## now again checking the distribution of the features
plt.figure(figsize=(15,15))
sns.set_style('darkgrid')
for i in range(len(bos.columns)):
    plt.subplot(4,4,i+1)
    sns.distplot(bos[bos.columns[i]],color='g')
plt.tight_layout()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2576727201.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bos[bos.columns[i]],color='g')
# C:\Users\shiva\AppData\Local\Temp\ipykernel_43756\2576727201.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #### Preprocessing operations to be done
# 1. Removing one of the features from RAD or TAX
# 2. replacing outliers with the null values
# 3. replacing null values with the mean of the column

# %%
## separating dependent and independent features
X = bos.drop(columns=['price'])
y = bos['price']

# %%
## creating a linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

lr = LinearRegression()
score_list = cross_val_score(lr,X,y,cv=5)
print(f"Cross validation score: {np.round(score_list.mean(),2)} +/- {np.round(score_list.std(),2)}.")
# Out:
# Cross validation score: 0.37 +/- 0.22.

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'price'],
#       dtype='object')

# %%
bos.describe().T[['mean','min','max']].loc['ZN']
# Out:
# mean     3.192922
# min      0.000000
# max     30.000000
# Name: ZN, dtype: float64

# %%
bos['CHAS'].mode()
# Out:
# 0    0.0
# Name: CHAS, dtype: float64
